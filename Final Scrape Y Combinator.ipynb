# %% [markdown]
# ## Scraped Y Combinator's Top Companies and Added Data Into Excel

# %%
import csv
import requests
import urllib.request
from bs4 import BeautifulSoup

url = 'https://www.ycombinator.com/topcompanies/'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html)

# %%
rows = soup.findAll("div", class_="detailsBox")

# %%
file = open('ycombo.csv', 'w')
writer = csv.writer(file)

#write writer row
writer.writerow(['ranks','company', 'founders','sector','jobs_created','company_description','batch', 'link'])

for row in rows:
    rank = row.find('span').text.strip()
    company = row.find('b').text.strip()
    founders = row.p.find_next_sibling().find_next_sibling().text.strip()
    sector = row.findAll('p')[3].text.strip()
    jobs_created = row.findAll('p')[4].text
    company_description = row.findAll('p')[0].text
    batch = row.findAll('p')[7].text
    link = row.find('a').attrs['href']
    
#     print(rank, ' ', company, ' ', founders, ' ', sector, ' ', jobs_created, ' ', company_description
#          ,' ', link)
    writer.writerow([rank, company, founders, sector, jobs_created, company_description, batch, link])

# %%
import pandas as pd
pd.read_csv('ycombo.csv')
# Out:
#    ranks          company                                           founders  \
# 0    #01           Stripe                 Patrick Collison and John Collison
# 1    #02           Airbnb       Brian Chesky, Joe Gebbia, Nathan Blecharczyk
# 2    #03           Cruise                           Kyle Vogt and Daniel Kan
# 3    #04         DoorDash                   Tony Xu, Andy Fang, Stanley Tang
# 4    #05         Coinbase                    Brian Armstrong and Fred Ehrsam
# 5    #06        Instacart        Apoorva Mehta, Max Mullen, Brandon Leonardo
# 6    #07          Dropbox                    Drew Houston and Arash Ferdowsi
# 7    #08  Ginkgo Bioworks  Reshma Shetty, Austin Che, Barry Canton, Tom K...
# 8    #09            Gusto               Josh Reeves, Eddie Kim, Tomer London
# 9    #10         Flexport                                      Ryan Petersen
# 10   #11            Rappi  Simon Borrero, Felipe Villamarin, Sebastian Mejia
# 11   #12             Brex             Henrique Dubugras and Pedro Franceschi
# 12   #13           Reddit                   Steve Huffman and Alexis Ohanian
# 13   #14           GitLab             Sid Sijbrandij and Dmitriy Zaporozhets
# 14   #15  PagerDuty, Inc.   Alex Solomon, Baskar Puvanathasan, Andrew Miklas
# 15   #16      Checkr, Inc               Daniel Yanisse and Jonathan Perichon
# 16   #17          Segment  Peter Reinhardt, Calvin French-Owen, Ilya Volo...
# 17   #18           Docker                                      Solomon Hykes
# 18   #19            Scale                                      Alexandr Wang
# 19   #20            Faire         Max Rhodes, Daniele Perito, Marcelo Cortes
# 20   #21           Twitch  Emmett Shear, Justin Kan, Michael Seibel, Kyle...
# 21   #22         PlanGrid  Ralph Gootee, Antoine Hersen, Kenny Stone, Rya...
# 22   #23         Mixpanel                       Suhail Doshi and Tim Trefren
# 23   #24        Amplitude           Spenser Skates, Curtis Liu, Jeffrey Wang
# 24   #25       Optimizely                        Pete Koomen and Dan Siroker
# 25   #26  Boom Supersonic                                       Blake Scholl
# 26   #27             Grin                      Sergio Romo and Jonathan Lewy
# 27   #28           Meesho                   Vidit Aatrey and Sanjeev Barnwal
# 28   #29          Algolia               Julien Lemoine and Nicolas Dessaigne
# 29   #30             GOAT                         Eddy Lu and Daishin Sugano
# ..   ...              ...                                                ...
# 46   #47         Ironclad                      Jason Boehmig and Cai GoGwilt
# 47   #48         Newfront                    Spike Lipkin and Gordon Wintrob
# 48   #49       InfluxData                           Paul Dix and Todd Persen
# 49   #50          Webflow        Vlad Magdalin, Sergie Magdalin, Bryant Chou
# 50   #51        People.ai                                     Oleg Rogynskyy
# 51   #52           Weebly            David Rusenko, Chris Fanini, Dan Veltri
# 52   #53           Xendit     Tessa Wijaya, Bo Chen, Juan Gonzalez, Moses Lo
# 53   #54   Matterport Inc          David Gausebeck, Matt Bell, Michael Beebe
# 54   #55         EasyPost                                   Jarrett Streebin
# 55   #56             Sift                    Jason Tan and Brandon Ballinger
# 56   #57     The Athletic                      Alex Mather and Adam Hansmann
# 57   #58       Mattermost                           Ian Tien and Corey Hulen
# 58   #59            WePay                      Rich Aberman and Bill Clerico
# 59   #60          Vidyard                    Devon Galloway and Michael Litt
# 60   #61            Weave          Brandon Rodman, Jared Rodman, Clint Berry
# 61   #62             Nurx                Hans Gangeskar and Edvard Engaeseth
# 62   #63      Proxy, Inc.                        Denis Mars and Simon Ranter
# 63   #64             Heap                    Matin Movassate and Ravi Parikh
# 64   #65           Presto                                           Raj Suri
# 65   #66          Payfazz              Hendra Kwik, Ricky Winata, Jefriyanto
# 66   #67           memsql        Nikita Shamgunov, Adam Prout, Eric Frenkiel
# 67   #68         Fivetran                     George Fraser and Taylor Brown
# 68   #69         Rippling                  Parker Conrad and Prasanna Sankar
# 69   #70           Clever          Tyler Bosmeny, Dan Carroll, Rafael Garcia
# 70   #71           Heroku        Orion Henry, James Lindenbaum, Adam Wiggins
# 71   #72        Fivestars                         Victor Ho and Matthew Doka
# 72   #73           CoreOS                     Brandon Philips and Alex Polvi
# 73   #74         ClearTax       Archit Gupta, Srivatsan Chari, Ankit Solanki
# 74   #75  Quero Education        Bernardo Pádua, Lucas Gomes, Thiago Brandão
# 75   #76         Ridecell                Aarjav Trivedi, ArunKumar Elangovan
#
#                                sector  jobs_created  \
# 0   Financial Technology and Services          2000
# 1         Consumer Goods and Services          6000
# 2                          Automotive          1500
# 3         Consumer Goods and Services          1800
# 4   Financial Technology and Services          1000
# 5         Consumer Goods and Services          1100
# 6           B2B Software and Services          2300
# 7                             Biotech           270
# 8           B2B Software and Services          1000
# 9           B2B Software and Services          1700
# 10        Consumer Goods and Services          3900
# 11  Financial Technology and Services           300
# 12                     Consumer Media           500
# 13          B2B Software and Services           842
# 14          B2B Software and Services           524
# 15          B2B Software and Services           400
# 16          B2B Software and Services           440
# 17          B2B Software and Services           400
# 18          B2B Software and Services            90
# 19          B2B Software and Services           240
# 20                     Consumer Media          1500
# 21                       Construction           450
# 22          B2B Software and Services           475
# 23          B2B Software and Services           300
# 24          B2B Software and Services           506
# 25                          Aerospace           150
# 26        Consumer Goods and Services          2000
# 27  Financial Technology and Services          1122
# 28          B2B Software and Services           338
# 29        Consumer Goods and Services           650
# ..                                ...           ...
# 46          B2B Software and Services           130
# 47  Financial Technology and Services           160
# 48          B2B Software and Services           150
# 49          B2B Software and Services           130
# 50          B2B Software and Services           125
# 51          B2B Software and Services           350
# 52  Financial Technology and Services           170
# 53          B2B Software and Services           870
# 54          B2B Software and Services           300
# 55          B2B Software and Services           190
# 56                     Consumer Media           500
# 57          B2B Software and Services            80
# 58  Financial Technology and Services           300
# 59          B2B Software and Services           300
# 60          B2B Software and Services           500
# 61                         Healthcare           250
# 62          B2B Software and Services            52
# 63          B2B Software and Services           170
# 64          B2B Software and Services           150
# 65  Financial Technology and Services           400
# 66          B2B Software and Services           200
# 67          B2B Software and Services           160
# 68          B2B Software and Services           165
# 69                          Education           150
# 70          B2B Software and Services           300
# 71          B2B Software and Services           360
# 72          B2B Software and Services           140
# 73  Financial Technology and Services           450
# 74                          Education           630
# 75                         Automotive           200
#
#                                   company_description batch  \
# 0   Stripe builds economic infrastructure for the ...   S09
# 1   Airbnb exists to create a world where anyone c...   W09
# 2   Cruise is building the world’s most advanced, ...   W14
# 3   Starting with restaurants, DoorDash is buildin...   S13
# 4   Coinbase is the easiest and most trusted place...   S12
# 5   Instacart is the North American leader in groc...   S12
# 6   Dropbox is a leading global collaboration plat...   S07
# 7   Ginkgo Bioworks is a biotech company that prog...   S14
# 8   Gusto is the people platform that provides sma...   W12
# 9   Freight forwarding is the circulatory system f...   W14
# 10  Rappi is building on-demand delivery and finan...   W16
# 11                  Brex does corporate credit cards.   W17
# 12  Reddit is a network of communities where indiv...   S05
# 13  GitLab is a complete DevOps platform, delivere...   W15
# 14  PagerDuty acts as the central nervous system f...   S10
# 15  Checkr is disrupting the background check indu...   S14
# 16  Segment is the world's leading provider of Cus...   S11
# 17  Docker provides a platform for building, shari...   S10
# 18  Scale builds infrastructure to accelerate the ...   S16
# 19  Faire is a curated wholesale marketplace conne...   W17
# 20  Twitch is a global community that comes togeth...   W07
# 21  PlanGrid builds construction software. Acquire...   W12
# 22  With Mixpanel, companies can analyze how and w...   S09
# 23  Amplitude is the world's #1 product intelligen...   W12
# 24  Optimizely offers a complete set of digital ex...   W10
# 25  Boom Supersonic is building Overture, history’...   W16
# 26  Grin is a micromobility and payments platform ...   S18
# 27  Meesho is India's largest social commerce plat...   S16
# 28  Algolia is the search-as-a-service platform th...   W14
# 29  GOAT Group is the world’s largest marketplace ...   W11
# ..                                                ...   ...
# 46  Ironclad is the digital contracting platform l...   W15
# 47  Newfront is building the modern platform to tr...   W18
# 48  InfluxData, creator of the open source time se...   W13
# 49  Webflow is a visual web development platform o...   S13
# 50  People.ai accelerates enterprise growth throug...   S16
# 51  Weebly allows anyone to start and grow an onli...   W07
# 52  Xendit provides localized payments for Southea...   S15
# 53  Matterport is the world leader in immersive 3D...   W12
# 54  EasyPost builds logistics infrastructure for t...   S13
# 55  Sift builds trust & safety solutions that secu...   S11
# 56  The Athletic is subscription sports media for ...   S16
# 57  Mattermost is an open source alternative to Sl...   S12
# 58  WePay is an integrated payments provider that ...   S09
# 59  Vidyard is a video platform that helps busines...   S11
# 60  Weave is a customer communication platform for...   W14
# 61  Nurx provides convenient, affordable, and pers...   W16
# 62  Proxy is a digital identity platform that empo...   S16
# 63  Heap automatically captures every user interac...   W13
# 64  Presto is the leading provider of enterprise S...     —
# 65  Payfazz creates a distributed network of bank ...   S17
# 66  MemSQL is a distributed, highly-scalable SQL d...   W11
# 67  Fivetran is a zero-configuration, fully-manage...   W13
# 68  Rippling is the first way for businesses to ma...   W17
# 69  Clever brings all K-12 schools' apps into one ...   S12
# 70  Heroku is a cloud platform that developers use...   W08
# 71  Fivestars is the largest rewards program for l...   W11
# 72  CoreOS develops open source tools that are the...   S13
# 73  ClearTax is the modern tax and finance platfor...   S14
# 74  Quero is a marketplace for higher education in...   S16
# 75  Ridecell provides the technology needed to run...   W12
#
#                                                  link
# 0                             https://stripe.com/jobs
# 1                         https://careers.airbnb.com/
# 2                       https://getcruise.com/careers
# 3                   https://www.doordash.com/careers/
# 4         https://www.coinbase.com/careers/positions?
# 5                   https://www.instacartcareers.com/
# 6                        https://www.dropbox.com/jobs
# 7             https://www.ginkgobioworks.com/careers/
# 8                     https://gusto.com/about/careers
# 9                   https://www.flexport.com/careers/
# 10                        https://jobs.lever.co/rappi
# 11                          https://careers.brex.com/
# 12                  https://www.redditinc.com/careers
# 13                     https://about.gitlab.com/jobs/
# 14    https://www.pagerduty.com/careers/#pd-positions
# 15                        https://checkr.com/careers/
# 16                          https://segment.com/jobs/
# 17                     https://www.docker.com/careers
# 18                          https://scale.com/careers
# 19                      https://www.faire.com/careers
# 20                        https://www.twitch.tv/jobs/
# 21                  https://www.plangrid.com/careers/
# 22                         https://mixpanel.com/jobs/
# 23                      https://amplitude.com/careers
# 24                https://www.optimizely.com/careers/
# 25                 https://boomsupersonic.com/careers
# 26                https://boards.greenhouse.io/grow99
# 27                            https://meesho.com/tech
# 28                   https://www.algolia.com/careers/
# 29                       https://www.goat.com/careers
# ..                                                ...
# 46                    https://ironcladapp.com/careers
# 47            https://jobs.lever.co/newfrontinsurance
# 48                https://www.influxdata.com/careers/
# 49                           https://webflow.com/jobs
# 50                     https://www.people.ai/careers/
# 51                       https://squareup.com/careers
# 52                  https://www.xendit.co/en/careers/
# 53                    https://matterport.com/careers/
# 54                          https://easypost.com/jobs
# 55                           https://sift.com/careers
# 56                  https://jobs.lever.co/theathletic
# 57                    https://mattermost.com/careers/
# 58                      https://go.wepay.com/careers/
# 59                     http://www.vidyard.com/careers
# 60                              http://www.weave.jobs
# 61                      https://www.nurx.com/careers/
# 62                         https://www.proxy.com/jobs
# 63                       https://heap.io/careers/jobs
# 64                       https://jobs.lever.co/presto
# 65                    https://www.payfazz.com/careers
# 66                          http://memsql.com/careers
# 67                       https://fivetran.com/careers
# 68                     https://jobs.lever.co/rippling
# 69                   https://clever.com/about/careers
# 70                     https://www.heroku.com/careers
# 71                 https://www.fivestars.com/careers/
# 72                     https://www.redhat.com/en/jobs
# 73  https://cleartax.in/s/career?ref=homepage-navb...
# 74                  https://quero.education/carreiras
# 75                https://ridecell.com/about/careers/
#
# [76 rows x 8 columns]

# %% [markdown]
# Huge help to this youtuber = # https://www.youtube.com/watch?v=JfU1G1Ug6-k
# # End
